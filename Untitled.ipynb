# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_data_df = pd.read_csv('dataset/Train.csv')
test_data_df = pd.read_csv('dataset/Test.csv')

# %%
train_data_df[train_data_df['GL_Code']=='GL-6020600']
# Out:
#       Inv_Id  Vendor_Code     GL_Code  Inv_Amt  \
# 172    15255  VENDOR-2478  GL-6020600     8.97
# 214    15312  VENDOR-1406  GL-6020600     1.96
# 276    15397  VENDOR-1487  GL-6020600    79.82
# 924    16342  VENDOR-1768  GL-6020600    46.42
# 1010   16469  VENDOR-2013  GL-6020600    75.26
# 1112   16617  VENDOR-1121  GL-6020600    61.45
# 1275   16846  VENDOR-2373  GL-6020600    24.52
# 1416   17039  VENDOR-2281  GL-6020600    51.32
# 1494   17165  VENDOR-2015  GL-6020600    65.42
# 1663   17417  VENDOR-2001  GL-6020600     8.23
# 2359   18405  VENDOR-1227  GL-6020600    79.97
# 2666   18833  VENDOR-2299  GL-6020600    28.76
# 2726   18930  VENDOR-2443  GL-6020600     4.78
# 2775   19006  VENDOR-1093  GL-6020600    29.28
# 3118   19510  VENDOR-1927  GL-6020600    68.58
# 3154   19565  VENDOR-1850  GL-6020600    50.13
# 3279   19742  VENDOR-2478  GL-6020600    21.07
# 3282   19746  VENDOR-2015  GL-6020600    45.52
# 3306   19776  VENDOR-2126  GL-6020600    13.60
# 3468   20021  VENDOR-1288  GL-6020600     5.04
# 3594   20186  VENDOR-1965  GL-6020600    25.49
# 3710   20346  VENDOR-2015  GL-6020600    94.47
# 4149   20958  VENDOR-2379  GL-6020600    11.93
# 4482   21433  VENDOR-1088  GL-6020600     4.99
# 4521   21491  VENDOR-2013  GL-6020600    90.22
# 4647   21691  VENDOR-2015  GL-6020600    76.44
# 4894   22044  VENDOR-2543  GL-6020600    29.93
# 5038   22246  VENDOR-1090  GL-6020600    76.48
# 5054   22267  VENDOR-2023  GL-6020600    77.75
# 5118   22358  VENDOR-1510  GL-6020600    77.86
# 5375   22717  VENDOR-2372  GL-6020600    79.59
# 5425   22795  VENDOR-1535  GL-6020600    28.66
#
#                                        Item_Description Product_Category
# 172   Aug 2000 Flightsafety International Inc Charit...       CLASS-1322
# 214   Belo & Co 2019Jan Non-Procurable Miscellaneous...       CLASS-2015
# 276   Charity Organizations Nov 2008 Non-Procurable ...       CLASS-1322
# 924   Charity Organizations Jul-2014 Non-Procurable ...       CLASS-1322
# 1010  Detrex Corporation Charity Organizations Jun20...       CLASS-1322
# 1112  Charity Organizations Non-Procurable Charity O...       CLASS-1322
# 1275  Non-Procurable Charity Organizations Flexsteel...       CLASS-1322
# 1416  Taxes Non-Procurable Taxes Taxes Oct-2015 Fede...       CLASS-2146
# 1494  Charity Organizations 2011May Non-Procurable D...       CLASS-1322
# 1663  Dempsey & Co Llc                              ...       CLASS-1322
# 2359  Charity Organizations Non-Procurable Charity O...       CLASS-1322
# 2666  Non-Procurable Charity Organizations Fidelity ...       CLASS-1322
# 2726  Non-Procurable Charity Organizations Friendly ...       CLASS-1322
# 2775  Bexy Communications Inc Charity Organizations ...       CLASS-1322
# 3118  Charity Organizations Non-Procurable Charity O...       CLASS-1322
# 3154  Non-Procurable Charity Organizations Continent...       CLASS-1322
# 3279  Charity Organizations Non-Procurable Flightsaf...       CLASS-1322
# 3282  Non-Procurable Charity Organizations Charity O...       CLASS-1322
# 3306  Non-Procurable Charity Organizations Charity O...       CLASS-1322
# 3468  Non-Procurable Royalties Associated Banc-Corp ...       CLASS-2015
# 3594  Charity Organizations Non-Procurable Charity O...       CLASS-1322
# 3710  Charity Organizations Jan 2013 Non-Procurable ...       CLASS-1322
# 4149  Non-Procurable Charity Organizations Duke Ener...       CLASS-1322
# 4482  Charity Organizations Non-Procurable Charity O...       CLASS-1322
# 4521  Non-Procurable Charity Organizations Charity O...       CLASS-1322
# 4647  Charity Organizations Charity Organizations Ch...       CLASS-1322
# 4894  Taxes Non-Procurable Frischs Restaurants Inc M...       CLASS-2146
# 5038  Charity Organizations Non-Procurable Charity O...       CLASS-1322
# 5054  Non-Procurable Charity Organizations Charity O...       CLASS-1322
# 5118  Charity Organizations Jan 2001 Non-Procurable ...       CLASS-1322
# 5375  Flamemaster Corp Charity Organizations Feb 200...       CLASS-1322
# 5425  Charity Organizations Charity Organizations Ch...       CLASS-1322

# %%
test_data_df[test_data_df['GL_Code']=='GL-6020600']
# Out:
#       Inv_Id  Vendor_Code     GL_Code  Inv_Amt  \
# 7      15026  VENDOR-2543  GL-6020600    26.08
# 118    15387  VENDOR-2357  GL-6020600    64.96
# 126    15418  VENDOR-1618  GL-6020600    33.10
# 159    15543  VENDOR-2015  GL-6020600    86.29
# 563    16822  VENDOR-1090  GL-6020600    91.79
# 859    17768  VENDOR-1532  GL-6020600    20.20
# 912    17947  VENDOR-1768  GL-6020600    34.21
# 1067   18495  VENDOR-1001  GL-6020600    16.57
# 1095   18605  VENDOR-1975  GL-6020600    15.14
# 1189   18889  VENDOR-1253  GL-6020600    19.22
# 1643   20380  VENDOR-1855  GL-6020600    69.69
# 1645   20397  VENDOR-1226  GL-6020600    99.72
# 1774   20834  VENDOR-1091  GL-6020600    54.01
# 1907   21272  VENDOR-2015  GL-6020600     3.85
# 1970   21494  VENDOR-1274  GL-6020600    27.56
# 2150   22053  VENDOR-1532  GL-6020600    30.46
# 2325   22659  VENDOR-2478  GL-6020600     7.82
# 2404   22904  VENDOR-1274  GL-6020600    51.33
# 2418   22931  VENDOR-2548  GL-6020600    50.99
#
#                                        Item_Description
# 7     Taxes Taxes Mar 2014 Frischs Restaurants Inc N...
# 118   Non-Procurable Charity Organizations First Sou...
# 126   Charity Organizations Non-Procurable Charity O...
# 159   Detroit Edison Co 2015-Apr  Non-Procurable Cha...
# 563   Charity Organizations Apr-2009 Non-Procurable ...
# 859   Charity Organizations Charity Organizations 20...
# 912   Colonial Bancorp Inc Qualified Stock Opt Chari...
# 1067  Royalties Non-Procurable K Tron International ...
# 1095  Non-Procurable Charity Organizations Charity O...
# 1189  Ara Services Inc Charity Organizations Oct-200...
# 1643  Charity Organizations Non-Procurable Continent...
# 1645  Feb 2012 Andersen Group Inc Charity Organizati...
# 1774  Charity Organizations Charity Organizations Ch...
# 1907  Charity Organizations Charity Organizations Au...
# 1970  Charity Organizations Non-Procurable Charity O...
# 2150  Charity Organizations Jan-2016 Non-Procurable ...
# 2325  Charity Organizations Charity Organizations Ap...
# 2404  Armstrong Associates Inc Dec2010 Non-Procurabl...
# 2418  Non-Procurable Charity Organizations Frigikar ...

# %%
len(train_data_df.Vendor_Code.unique())
# Out:
# 1253

# %%
# plt.hist(train_data_df['GL_Code'].value_counts())
# plt.show()
train_data_df['Product_Category'].value_counts().plot(kind='bar')

# %%
sns.heatmap(train_data_df.loc[:,['GL_Code','Product_Category']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-30441952ae93> in <module>
# ----> 1 sns.heatmap(train_data_df.loc[:,['GL_Code','Product_Category']])
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     165         # Determine good default values for the colormapping
#     166         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 167                                     cmap, center, robust)
#     168
#     169         # Sort out the annotations
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     202                                cmap, center, robust):
#     203         """Use some heuristics to set good defaults for colorbar and range."""
# --> 204         calc_data = plot_data.data[~np.isnan(plot_data.data)]
#     205         if vmin is None:
#     206             vmin = np.percentile(calc_data, 2) if robust else calc_data.min()
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
new_df = train_data_df.groupby(['GL_Code','Product_Category']).size().reset_index().rename(columns={0:'Size'})
pv = new_df.pivot("GL_Code", "Product_Category", "Size")
f, ax = plt.subplots(figsize=(36, 9))
sns.heatmap(pv, ax=ax).set_facecolor('#dedede')
plt.show()

# %%
new_df.GL_Code.unique()
# Out:
# array(['GL-2182000', 'GL-6020600', 'GL-6050100', 'GL-6050310',
#        'GL-6060100', 'GL-6100410', 'GL-6100500', 'GL-6101400',
#        'GL-6121905'], dtype=object)

# %%
new_df
# Out:
#        GL_Code Product_Category  Size
# 0   GL-2182000       CLASS-1248     5
# 1   GL-2182000       CLASS-1249   176
# 2   GL-2182000       CLASS-1250   451
# 3   GL-2182000       CLASS-1294    25
# 4   GL-2182000       CLASS-1376   365
# 5   GL-2182000       CLASS-1477    50
# 6   GL-2182000       CLASS-1688     4
# 7   GL-2182000       CLASS-1838     1
# 8   GL-2182000       CLASS-1867    15
# 9   GL-2182000       CLASS-1957     1
# 10  GL-2182000       CLASS-1964    28
# 11  GL-2182000       CLASS-2003    32
# 12  GL-2182000       CLASS-2141   108
# 13  GL-2182000       CLASS-2241    36
# 14  GL-6020600       CLASS-1322    28
# 15  GL-6020600       CLASS-2015     2
# 16  GL-6020600       CLASS-2146     2
# 17  GL-6050100       CLASS-1274   946
# 18  GL-6050100       CLASS-1983    16
# 19  GL-6050310       CLASS-1567    84
# 20  GL-6050310       CLASS-1758  1498
# 21  GL-6050310       CLASS-1870    36
# 22  GL-6060100       CLASS-1274    40
# 23  GL-6060100       CLASS-1522   102
# 24  GL-6060100       CLASS-1652    15
# 25  GL-6060100       CLASS-1983     1
# 26  GL-6100410       CLASS-1429    32
# 27  GL-6100410       CLASS-1828   113
# 28  GL-6100410       CLASS-1963   230
# 29  GL-6100410       CLASS-2038    13
# 30  GL-6100500       CLASS-1309    32
# 31  GL-6100500       CLASS-1721   107
# 32  GL-6100500       CLASS-1805    12
# 33  GL-6100500       CLASS-1850    60
# 34  GL-6100500       CLASS-2152     9
# 35  GL-6101400       CLASS-1522   749
# 36  GL-6101400       CLASS-2112    53
# 37  GL-6121905       CLASS-1770    19
# 38  GL-6121905       CLASS-1919    70
